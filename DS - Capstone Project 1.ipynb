# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: future in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: click in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: requests in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: ratelim in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: decorator in c:\users\toreleon\appdata\local\continuum\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import geocoder

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
r = requests.get(url)

soup = BeautifulSoup(r.content, 'html5lib')
table = soup.find('div', attrs ={'id':'container'})

# %%
postalCodes = [];
boroughs= [];
neighborhoods = [];
columnNum = 1;
passVal = False

for row in soup.find_all('td'):
    for cell in row:
        if cell.string and cell.string[0].isalpha() and len(cell.string) > 2:
            passVal = False
            if columnNum == 1:
                if passVal == False and cell.string[1].isdigit():
                    postalCodes.append(cell.string);   
                    columnNum = 2
                else:
                    continue
            elif columnNum == 2 :
                if cell.string == 'Not assigned':
                    passVal = True
                    del postalCodes[-1]
                    columnNum = 1
                    continue
                else:
                    boroughs.append(cell.string);      
                    columnNum = 3
            elif columnNum == 3 :
                if cell.string == 'Not assigned\n':
                    neighborhoods.append(boroughs[-1])
                else:
                    neighborhoods.append(cell.string); 
                columnNum = 1

# %%
# define the dataframe columns
column_names = ['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighbors = pd.DataFrame(columns=column_names)

neighbors
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
for data in range(0, len(postalCodes)-1):
    code = postalCodes[data]
    borough = boroughs[data]
    neighborhood_name = neighborhoods[data]
    
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(code))
    lat_lng_coords = g.latlng

    neighbors = neighbors.append({ 'PostalCode': code,
                                   'Borough': borough,
                                   'Neighborhood': neighborhood_name,
                                   'Latitude': lat_lng_coords[0],
                                   'Longitude': lat_lng_coords[1]}, ignore_index=True)

# %%
neighbors
# Out:
#     PostalCode           Borough                Neighborhood   Latitude  \
# 0          M3A        North York                   Parkwoods  43.752420
# 1          M4A        North York            Victoria Village  43.730600
# 2          M5A  Downtown Toronto                Harbourfront  43.650295
# 3          M6A        North York            Lawrence Heights  43.723270
# 4          M6A        North York              Lawrence Manor  43.723270
# ..         ...               ...                         ...        ...
# 210        M8Y         Etobicoke                    Sunnylea  43.632835
# 211        M8Z         Etobicoke  Kingsway Park South West\n  43.624630
# 212        M8Z         Etobicoke                   Mimico NW  43.624630
# 213        M8Z         Etobicoke          The Queensway West  43.624630
# 214        M8Z         Etobicoke     Royal York South West\n  43.624630
#
#      Longitude
# 0   -79.329242
# 1   -79.313265
# 2   -79.359166
# 3   -79.451286
# 4   -79.451286
# ..         ...
# 210 -79.489550
# 211 -79.526950
# 212 -79.526950
# 213 -79.526950
# 214 -79.526950
#
# [215 rows x 5 columns]
